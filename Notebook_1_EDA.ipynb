# %% [markdown]
# # What we know about our data?
#
# Molecular dynamics

# %%
import pandas as pd

# %% [markdown]
# ## 1. Trajectories analysis

# %%
data = pd.read_csv("hbq_data_215.csv")

# %%
data["mu_z"].hist()
# Out:
# <Axes: >

# %% [markdown]
# ## 2. Data preparation
